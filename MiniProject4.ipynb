# %%
import pandas as pd

# %%
# Read dataset(csv file)

# %%
path=r"C:\Users\HP\Desktop\3rd year\2nd Sem\DSBDAL\Dataset\Covid19\covid_vaccine_statewise.csv"

# %%
data=pd.read_csv(path)

# %%
# Display dataset

# %%
data
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
data.tail(8)
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 7837  08/08/2021  West Bengal                32098768.0  271684.0    584.0
# 7838  09/08/2021  West Bengal                32390378.0  866173.0   2086.0
# 7839  10/08/2021  West Bengal                       NaN       NaN      NaN
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 7837               23017864.0                 9080904.0
# 7838               23257417.0                 9132961.0
# 7839                      NaN                       NaN
# 7840                      NaN                       NaN
# ...

# %%
# Describe dataset

# %%
data.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
data.groupby('State')

# %%
# First Dose Administered

# %%
FirstDoseData=data.groupby('State')['First Dose Administered'].last()
FirstDoseData.drop('India', inplace=True)
FirstDoseData
# Out:
# State
# Andaman and Nicobar Islands                   216046.0
# Andhra Pradesh                              17628583.0
# Arunachal Pradesh                             692475.0
# Assam                                       10495293.0
# Bihar                                       23350171.0
# Chandigarh                                    700285.0
# Chhattisgarh                                 9181482.0
# Dadra and Nagar Haveli and Daman and Diu      584370.0
# Delhi                                        7835546.0
# Goa                                          1094392.0
# Gujarat                                     28101222.0
# Haryana                                     10086831.0
# Himachal Pradesh                             4249849.0
# Jammu and Kashmir                            5318516.0
# Jharkhand                                    8382280.0
# Karnataka                                   25847691.0
# Kerala                                      15670747.0
# ...

# %%
FirstDoseData.plot(kind='bar')

# %%
# Second Dose Administered

# %%
SecondDoseData=data.groupby('State')['Second Dose Administered'].last()
SecondDoseData.drop('India', inplace=True)
SecondDoseData
# Out:
# State
# Andaman and Nicobar Islands                    94597.0
# Andhra Pradesh                               6214312.0
# Arunachal Pradesh                             186619.0
# Assam                                        2208577.0
# Bihar                                        4484768.0
# Chandigarh                                    223534.0
# Chhattisgarh                                 2587695.0
# Dadra and Nagar Haveli and Daman and Diu       80851.0
# Delhi                                        3000536.0
# Goa                                           302519.0
# Gujarat                                      9051153.0
# Haryana                                      2923550.0
# Himachal Pradesh                             1382592.0
# Jammu and Kashmir                            1489826.0
# Jharkhand                                    1996014.0
# Karnataka                                    7432852.0
# Kerala                                       6426984.0
# ...

# %%
SecondDoseData.plot(kind='bar')

# %%
# Males vaccinated

# %%
MaleDose=data.groupby('State') ['Male (Doses Administered)'].last()
MaleDose.drop('India',inplace=True)
M=MaleDose.sum()
M
# Out:
# 270163622.0

# %%
# Females vaccinated

# %%
FemaleDose=data.groupby('State') ['Female (Doses Administered)'].last()
FemaleDose.drop('India',inplace=True)
F=FemaleDose.sum()
F
# Out:
# 239518609.0
